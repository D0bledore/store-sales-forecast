# %% [markdown]
# # 03 - Model Training

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this phase, we begin training forecasting models aimed at helping Corporación Favorita improve inventory management. Having already identified stockout patterns, promotion effectiveness, and sales dynamics at both the product and store levels, we now focus on predicting future demand. These predictions will serve as input for smarter stock replenishment strategies, reducing understocking and overstocking risks across locations.
#
# We will be using Facebook Prophet, a robust time series forecasting tool, well-suited for daily retail data that may contain missing values, multiple seasonalities, and external regressors such as promotions or oil prices. This model supports explainable forecasting with trend and holiday components—making it ideal for our business use case.
#
# ---

# %% [markdown]
# ## Objectives
#
# - Train a forecasting model (Prophet) to predict daily sales for each store-product-family combination.
# - Incorporate business-relevant features such as promotions, holidays, and oil prices to improve forecast accuracy.
# - Use recent time windows to validate model performance against real-world behavior.
# - Identify where improved stocking strategies could yield the most business value.

# %% [markdown]
# ## 1. Import & Load Data

# %%
# --- Import necessary modules ---
import pandas as pd
from prophet import Prophet
import matplotlib.pyplot as plt

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# --- Load prepared inventory dataset ---
df = pd.read_csv("../data/processed/inventory_prepared.csv", parse_dates=['date'])

# --- Preview ---
df.head()
# Out:
#      id       date  store_nbr      family  sales  onpromotion  transactions  \
# 0     0 2013-01-01          1  AUTOMOTIVE    0.0            0           0.0
# 1  1782 2013-01-02          1  AUTOMOTIVE    2.0            0        2111.0
# 2  3564 2013-01-03          1  AUTOMOTIVE    3.0            0        1833.0
# 3  5346 2013-01-04          1  AUTOMOTIVE    3.0            0        1863.0
# 4  7128 2013-01-05          1  AUTOMOTIVE    5.0            0        1509.0
#
#    dcoilwtico   city      state type  cluster  is_holiday  rolling_avg_7  \
# 0       93.14  Quito  Pichincha    D       13           1       0.000000
# 1       93.14  Quito  Pichincha    D       13           0       1.000000
# 2       92.97  Quito  Pichincha    D       13           0       1.666667
# 3       93.12  Quito  Pichincha    D       13           0       2.000000
# 4       93.12  Quito  Pichincha    D       13           1       2.600000
#
#    rolling_avg_14  sales_lag_1  sales_lag_7  sales_lag_14
# 0        0.000000          NaN          NaN           NaN
# 1        1.000000          0.0          NaN           NaN
# 2        1.666667          2.0          NaN           NaN
# 3        2.000000          3.0          NaN           NaN
# 4        2.600000          3.0          NaN           NaN

# %% [markdown]
# ## 2. Prepare Data for Prophet

# %% [markdown]
# ### 2.1. Load Dataset and Prepare Dataset

# %% [markdown]
# Load the cleaned and feature-engineered dataset (`inventory_prepared.csv`).

# %%
# Load prepared dataset
df = pd.read_csv("../data/processed/inventory_prepared.csv", parse_dates=["date"])

# %% [markdown]
# We format the dataset to match Prophet’s required structure—`ds` for dates and `y` for target values—so the model can correctly interpret and forecast time series data, while adding relevant regressors (like promotions or holidays) helps improve forecast accuracy by capturing external influences on sales.  We also drop any rows with missing values in target or regressors.

# %%
# Rename target and date for Prophet
df['y'] = df['sales']
df['ds'] = df['date']

# Drop rows with missing target or regressors
df = df.dropna(subset=['y', 'rolling_avg_7', 'sales_lag_1', 'sales_lag_7'])

# %% [markdown]
# ### 2.2. Train Prophet Per Store-Family Combination
# We iterate through each unique `(store_nbr, family)` pair, train a Prophet model including key regressors (rolling averages, lags, promotions, etc.), and skip combos with insufficient data.

# %%
import os

# Get unique store-family combinations
combinations = df[['store_nbr', 'family']].drop_duplicates()

# Prepare directory to save forecasts
os.makedirs("../forecasts", exist_ok=True)

# %% [markdown]
# ### 2.3. Forecast Next 14 Days
#
# To avoid missing values in future regressors (like rolling averages and sales lags), we forecast on the last 14 observed days for each (store, family) combination. These days already contain all the necessary features, ensuring reliable predictions without imputation or data leakage.
#
# While this does not extend into future unseen dates, it simulates how the model would behave in a real scenario by using the most recent available data. This provides both a stable foundation for validation and insights into how the model responds to known patterns — aligning with our inventory management goals.

# %%
from tqdm import tqdm

# Forecast horizon (e.g., next 14 days)
forecast_days = 14
forecast_results = []

# Loop through each store-family combo and train + forecast
for _, row in tqdm(combinations.iterrows(), total=len(combinations)):
    store = row['store_nbr']
    family = row['family']
    subset = df[(df['store_nbr'] == store) & (df['family'] == family)].copy()

    if len(subset) < 100:  # Not enough data to train
        continue

    # Define training data
    train_df = subset[['ds', 'y', 'rolling_avg_7', 'sales_lag_1', 'sales_lag_7',
                       'onpromotion', 'transactions', 'dcoilwtico', 'is_holiday']]

    # Fit model
    model = Prophet()
    model.add_regressor('rolling_avg_7')
    model.add_regressor('sales_lag_1')
    model.add_regressor('sales_lag_7')
    model.add_regressor('onpromotion')
    model.add_regressor('transactions')
    model.add_regressor('dcoilwtico')
    model.add_regressor('is_holiday')
    model.fit(train_df)

    # Create future dataframe with same regressors
    future = subset[['ds', 'rolling_avg_7', 'sales_lag_1', 'sales_lag_7',
                     'onpromotion', 'transactions', 'dcoilwtico', 'is_holiday']].copy()
    future = future.sort_values('ds').tail(forecast_days)

    # Forecast
    forecast = model.predict(future)
    forecast['store_nbr'] = store
    forecast['family'] = family
    forecast['yhat'] = forecast['yhat'].clip(lower=0)  # No negative predictions
    forecast_results.append(forecast[['ds', 'store_nbr', 'family', 'yhat']])
# Out:
#   0%|          | 0/1782 [00:00<?, ?it/s]04:44:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 2/1782 [00:00<07:14,  4.10it/s]04:44:56 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 3/1782 [00:00<08:33,  3.46it/s]04:44:56 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:56 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 4/1782 [00:01<09:54,  2.99it/s]04:44:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 5/1782 [00:01<09:48,  3.02it/s]04:44:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 6/1782 [00:01<10:28,  2.83it/s]04:44:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 7/1782 [00:02<10:28,  2.83it/s]04:44:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:58 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 8/1782 [00:02<10:16,  2.88it/s]04:44:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:58 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 9/1782 [00:03<10:46,  2.74it/s]04:44:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 10/1782 [00:03<10:25,  2.83it/s]04:44:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 11/1782 [00:03<10:10,  2.90it/s]04:44:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:44:59 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 12/1782 [00:04<09:57,  2.96it/s]04:44:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:00 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 13/1782 [00:04<10:03,  2.93it/s]04:45:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:00 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 14/1782 [00:04<09:56,  2.97it/s]04:45:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:00 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 15/1782 [00:05<09:50,  2.99it/s]04:45:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:01 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 16/1782 [00:05<10:01,  2.94it/s]04:45:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:01 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 17/1782 [00:05<10:23,  2.83it/s]04:45:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:01 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 18/1782 [00:06<10:04,  2.92it/s]04:45:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:02 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 19/1782 [00:06<10:33,  2.78it/s]04:45:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:02 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 20/1782 [00:06<10:38,  2.76it/s]04:45:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:02 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 21/1782 [00:07<10:39,  2.75it/s]04:45:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:03 - cmdstanpy - INFO - Chain [1] done processing
#   1%|          | 22/1782 [00:07<10:39,  2.75it/s]04:45:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:03 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 23/1782 [00:07<10:15,  2.86it/s]04:45:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:03 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 24/1782 [00:08<10:29,  2.79it/s]04:45:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:04 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 25/1782 [00:08<10:32,  2.78it/s]04:45:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:04 - cmdstanpy - INFO - Chain [1] done processing
#   1%|▏         | 26/1782 [00:09<10:26,  2.80it/s]04:45:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:04 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 27/1782 [00:09<10:19,  2.83it/s]04:45:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:05 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 28/1782 [00:09<10:53,  2.68it/s]04:45:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:05 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 29/1782 [00:10<10:57,  2.66it/s]04:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:06 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 30/1782 [00:10<10:35,  2.76it/s]04:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:06 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 31/1782 [00:10<10:33,  2.76it/s]04:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:06 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 32/1782 [00:11<10:12,  2.86it/s]04:45:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:07 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 33/1782 [00:11<09:59,  2.92it/s]04:45:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:07 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 34/1782 [00:11<09:51,  2.96it/s]04:45:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:07 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 35/1782 [00:12<09:47,  2.98it/s]04:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:08 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 36/1782 [00:12<10:01,  2.90it/s]04:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:08 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 37/1782 [00:12<10:18,  2.82it/s]04:45:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:08 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 38/1782 [00:13<10:02,  2.89it/s]04:45:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:09 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 39/1782 [00:13<10:30,  2.76it/s]04:45:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:09 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 40/1782 [00:14<10:54,  2.66it/s]04:45:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:09 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 41/1782 [00:14<10:36,  2.73it/s]04:45:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:10 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 42/1782 [00:14<10:31,  2.75it/s]04:45:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:10 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 43/1782 [00:15<10:32,  2.75it/s]04:45:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:11 - cmdstanpy - INFO - Chain [1] done processing
#   2%|▏         | 44/1782 [00:15<10:33,  2.74it/s]04:45:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:11 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 45/1782 [00:15<11:02,  2.62it/s]04:45:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:11 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 46/1782 [00:16<10:35,  2.73it/s]04:45:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:12 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 47/1782 [00:16<10:22,  2.79it/s]04:45:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:12 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 48/1782 [00:16<10:09,  2.85it/s]04:45:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:12 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 49/1782 [00:17<10:03,  2.87it/s]04:45:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:13 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 50/1782 [00:17<09:59,  2.89it/s]04:45:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:13 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 51/1782 [00:17<09:42,  2.97it/s]04:45:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:13 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 52/1782 [00:18<10:06,  2.85it/s]04:45:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:14 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 53/1782 [00:18<10:05,  2.85it/s]04:45:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:14 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 54/1782 [00:18<10:10,  2.83it/s]04:45:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:14 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 55/1782 [00:19<10:27,  2.75it/s]04:45:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:15 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 56/1782 [00:19<10:19,  2.79it/s]04:45:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:15 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 57/1782 [00:20<10:19,  2.78it/s]04:45:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:16 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 58/1782 [00:20<10:43,  2.68it/s]04:45:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:16 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 59/1782 [00:20<10:24,  2.76it/s]04:45:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:16 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 60/1782 [00:21<10:07,  2.83it/s]04:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:17 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 61/1782 [00:21<10:07,  2.83it/s]04:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:17 - cmdstanpy - INFO - Chain [1] done processing
#   3%|▎         | 62/1782 [00:21<09:59,  2.87it/s]04:45:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:17 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 63/1782 [00:22<09:58,  2.87it/s]04:45:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:18 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 64/1782 [00:22<10:26,  2.74it/s]04:45:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:18 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 65/1782 [00:22<09:55,  2.88it/s]04:45:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:18 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▎         | 66/1782 [00:23<10:00,  2.86it/s]04:45:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:19 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 67/1782 [00:23<10:03,  2.84it/s]04:45:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:19 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 68/1782 [00:23<09:48,  2.91it/s]04:45:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:19 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 69/1782 [00:24<10:10,  2.80it/s]04:45:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:20 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 70/1782 [00:24<10:16,  2.78it/s]04:45:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:20 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 71/1782 [00:25<10:02,  2.84it/s]04:45:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:21 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 72/1782 [00:25<10:23,  2.74it/s]04:45:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:21 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 73/1782 [00:25<10:16,  2.77it/s]04:45:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:21 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 74/1782 [00:26<10:05,  2.82it/s]04:45:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:22 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 75/1782 [00:26<10:05,  2.82it/s]04:45:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:22 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 76/1782 [00:26<10:12,  2.78it/s]04:45:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:22 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 77/1782 [00:27<10:11,  2.79it/s]04:45:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 78/1782 [00:27<09:58,  2.85it/s]04:45:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 79/1782 [00:27<09:54,  2.87it/s]04:45:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:23 - cmdstanpy - INFO - Chain [1] done processing
#   4%|▍         | 80/1782 [00:28<09:50,  2.88it/s]04:45:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:24 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 81/1782 [00:28<09:53,  2.87it/s]04:45:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:24 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 82/1782 [00:28<10:19,  2.74it/s]04:45:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:24 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 83/1782 [00:29<10:16,  2.76it/s]04:45:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:25 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 84/1782 [00:29<09:54,  2.85it/s]04:45:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:25 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 85/1782 [00:30<10:26,  2.71it/s]04:45:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:26 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 86/1782 [00:30<10:20,  2.73it/s]04:45:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:26 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 87/1782 [00:30<10:20,  2.73it/s]04:45:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:26 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 88/1782 [00:31<10:06,  2.79it/s]04:45:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▍         | 89/1782 [00:31<10:06,  2.79it/s]04:45:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 90/1782 [00:31<10:27,  2.70it/s]04:45:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 91/1782 [00:32<10:35,  2.66it/s]04:45:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:28 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 92/1782 [00:32<10:16,  2.74it/s]04:45:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:28 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 93/1782 [00:32<10:17,  2.74it/s]04:45:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:28 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 94/1782 [00:33<10:17,  2.73it/s]04:45:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 95/1782 [00:33<10:02,  2.80it/s]04:45:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:29 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 96/1782 [00:34<09:48,  2.87it/s]04:45:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:30 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 97/1782 [00:34<10:04,  2.79it/s]04:45:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:30 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 98/1782 [00:34<09:58,  2.81it/s]04:45:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:30 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 99/1782 [00:35<09:59,  2.81it/s]04:45:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:31 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 100/1782 [00:35<09:48,  2.86it/s]04:45:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:31 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 101/1782 [00:35<09:52,  2.84it/s]04:45:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:31 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 102/1782 [00:36<09:37,  2.91it/s]04:45:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:32 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 103/1782 [00:36<09:47,  2.86it/s]04:45:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:32 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 104/1782 [00:36<09:39,  2.90it/s]04:45:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:32 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 105/1782 [00:37<09:42,  2.88it/s]04:45:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:33 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 106/1782 [00:37<10:05,  2.77it/s]04:45:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:33 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 107/1782 [00:37<10:09,  2.75it/s]04:45:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:33 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 108/1782 [00:38<10:00,  2.79it/s]04:45:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:34 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 109/1782 [00:38<10:30,  2.65it/s]04:45:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:34 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 110/1782 [00:39<10:24,  2.68it/s]04:45:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:35 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▌         | 111/1782 [00:39<10:13,  2.73it/s]04:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:35 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 112/1782 [00:39<09:57,  2.79it/s]04:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:35 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 113/1782 [00:40<09:41,  2.87it/s]04:45:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:36 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 114/1782 [00:40<09:24,  2.95it/s]04:45:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:36 - cmdstanpy - INFO - Chain [1] done processing
#   6%|▋         | 115/1782 [00:40<09:42,  2.86it/s]04:45:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:36 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 116/1782 [00:41<09:45,  2.84it/s]04:45:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:37 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 117/1782 [00:41<09:43,  2.85it/s]04:45:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:37 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 118/1782 [00:41<09:57,  2.78it/s]04:45:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:37 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 119/1782 [00:42<10:09,  2.73it/s]04:45:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:38 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 120/1782 [00:42<10:12,  2.72it/s]04:45:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:38 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 121/1782 [00:42<10:06,  2.74it/s]04:45:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:38 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 122/1782 [00:43<09:44,  2.84it/s]04:45:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:39 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 123/1782 [00:43<09:53,  2.79it/s]04:45:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:39 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 124/1782 [00:43<09:42,  2.85it/s]04:45:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:39 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 125/1782 [00:44<09:29,  2.91it/s]04:45:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:40 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 126/1782 [00:44<09:42,  2.84it/s]04:45:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:40 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 127/1782 [00:45<09:36,  2.87it/s]04:45:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:40 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 128/1782 [00:45<09:39,  2.85it/s]04:45:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:41 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 129/1782 [00:45<09:49,  2.80it/s]04:45:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:41 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 130/1782 [00:46<10:05,  2.73it/s]04:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:42 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 131/1782 [00:46<09:42,  2.83it/s]04:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:42 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 132/1782 [00:46<09:51,  2.79it/s]04:45:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:42 - cmdstanpy - INFO - Chain [1] done processing
#   7%|▋         | 133/1782 [00:47<09:42,  2.83it/s]04:45:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:43 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 134/1782 [00:47<09:48,  2.80it/s]04:45:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:43 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 135/1782 [00:47<09:50,  2.79it/s]04:45:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:43 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 136/1782 [00:48<09:57,  2.76it/s]04:45:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:44 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 137/1782 [00:48<09:37,  2.85it/s]04:45:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:44 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 138/1782 [00:48<09:33,  2.86it/s]04:45:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:44 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 139/1782 [00:49<10:02,  2.73it/s]04:45:45 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:45 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 140/1782 [00:49<10:09,  2.69it/s]04:45:45 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:45 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 141/1782 [00:50<10:21,  2.64it/s]04:45:46 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:46 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 142/1782 [00:50<10:15,  2.66it/s]04:45:46 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:46 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 143/1782 [00:50<10:13,  2.67it/s]04:45:46 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:46 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 144/1782 [00:51<10:25,  2.62it/s]04:45:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:47 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 145/1782 [00:51<10:19,  2.64it/s]04:45:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:47 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 146/1782 [00:51<10:00,  2.72it/s]04:45:47 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:47 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 147/1782 [00:52<09:39,  2.82it/s]04:45:48 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:48 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 148/1782 [00:52<09:31,  2.86it/s]04:45:48 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:48 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 149/1782 [00:52<09:25,  2.89it/s]04:45:48 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:48 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 150/1782 [00:53<09:21,  2.91it/s]04:45:49 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:49 - cmdstanpy - INFO - Chain [1] done processing
#   8%|▊         | 151/1782 [00:53<09:45,  2.79it/s]04:45:49 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:49 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▊         | 152/1782 [00:54<10:01,  2.71it/s]04:45:50 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:50 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▊         | 153/1782 [00:54<09:40,  2.81it/s]04:45:50 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:50 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▊         | 154/1782 [00:54<09:56,  2.73it/s]04:45:50 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:50 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▊         | 155/1782 [00:55<09:39,  2.81it/s]04:45:51 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:51 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 156/1782 [00:55<09:52,  2.74it/s]04:45:51 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:51 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 157/1782 [00:55<10:00,  2.71it/s]04:45:51 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:51 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 158/1782 [00:56<10:00,  2.71it/s]04:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:52 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 159/1782 [00:56<09:44,  2.78it/s]04:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:52 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 160/1782 [00:57<09:54,  2.73it/s]04:45:52 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:53 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 161/1782 [00:57<10:06,  2.67it/s]04:45:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:53 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 162/1782 [00:57<10:07,  2.67it/s]04:45:53 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:53 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 163/1782 [00:58<10:14,  2.63it/s]04:45:54 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:54 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 164/1782 [00:58<09:45,  2.76it/s]04:45:54 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:54 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 165/1782 [00:58<09:34,  2.81it/s]04:45:54 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:54 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 166/1782 [00:59<09:44,  2.76it/s]04:45:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:55 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 167/1782 [00:59<09:32,  2.82it/s]04:45:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:55 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 168/1782 [00:59<09:16,  2.90it/s]04:45:55 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:55 - cmdstanpy - INFO - Chain [1] done processing
#   9%|▉         | 169/1782 [01:00<09:26,  2.85it/s]04:45:56 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:56 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 170/1782 [01:00<09:07,  2.94it/s]04:45:56 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:56 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 171/1782 [01:00<09:30,  2.82it/s]04:45:56 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:56 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 172/1782 [01:01<09:29,  2.83it/s]04:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:57 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 173/1782 [01:01<09:27,  2.84it/s]04:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:57 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 174/1782 [01:02<09:34,  2.80it/s]04:45:57 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:57 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 175/1782 [01:02<09:22,  2.86it/s]04:45:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:58 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 176/1782 [01:02<09:10,  2.92it/s]04:45:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:58 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 177/1782 [01:02<09:01,  2.97it/s]04:45:58 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:58 - cmdstanpy - INFO - Chain [1] done processing
#  10%|▉         | 178/1782 [01:03<09:10,  2.92it/s]04:45:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:59 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 179/1782 [01:03<09:21,  2.86it/s]04:45:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:45:59 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 180/1782 [01:04<09:06,  2.93it/s]04:45:59 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:00 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 181/1782 [01:04<09:11,  2.91it/s]04:46:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:00 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 182/1782 [01:04<09:21,  2.85it/s]04:46:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:00 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 183/1782 [01:05<09:09,  2.91it/s]04:46:00 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:01 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 184/1782 [01:05<09:13,  2.89it/s]04:46:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:01 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 185/1782 [01:05<09:20,  2.85it/s]04:46:01 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:01 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 186/1782 [01:06<09:25,  2.82it/s]04:46:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:02 - cmdstanpy - INFO - Chain [1] done processing
#  10%|█         | 187/1782 [01:06<09:21,  2.84it/s]04:46:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:02 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 188/1782 [01:06<09:10,  2.89it/s]04:46:02 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:02 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 189/1782 [01:07<09:14,  2.87it/s]04:46:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:03 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 190/1782 [01:07<09:05,  2.92it/s]04:46:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:03 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 191/1782 [01:07<09:00,  2.94it/s]04:46:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:03 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 192/1782 [01:08<09:01,  2.94it/s]04:46:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:04 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 193/1782 [01:08<09:11,  2.88it/s]04:46:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:04 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 194/1782 [01:08<09:10,  2.89it/s]04:46:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:04 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 195/1782 [01:09<09:06,  2.91it/s]04:46:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:05 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 196/1782 [01:09<09:40,  2.73it/s]04:46:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:05 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 197/1782 [01:10<10:04,  2.62it/s]04:46:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:06 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 198/1782 [01:10<09:53,  2.67it/s]04:46:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:06 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 199/1782 [01:10<09:30,  2.77it/s]04:46:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:06 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 200/1782 [01:11<09:10,  2.88it/s]04:46:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:07 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 201/1782 [01:11<09:18,  2.83it/s]04:46:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:07 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 202/1782 [01:11<09:39,  2.72it/s]04:46:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:07 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 203/1782 [01:12<09:14,  2.85it/s]04:46:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:08 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█▏        | 204/1782 [01:12<09:17,  2.83it/s]04:46:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:08 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 205/1782 [01:12<09:16,  2.83it/s]04:46:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:08 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 206/1782 [01:13<08:56,  2.94it/s]04:46:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:09 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 207/1782 [01:13<09:21,  2.81it/s]04:46:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:09 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 208/1782 [01:13<09:06,  2.88it/s]04:46:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:09 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 209/1782 [01:14<09:09,  2.86it/s]04:46:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:10 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 210/1782 [01:14<09:02,  2.90it/s]04:46:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:10 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 211/1782 [01:14<08:57,  2.92it/s]04:46:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:10 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 212/1782 [01:15<08:47,  2.98it/s]04:46:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:11 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 213/1782 [01:15<08:49,  2.96it/s]04:46:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:11 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 214/1782 [01:15<09:09,  2.85it/s]04:46:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:11 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 215/1782 [01:16<09:14,  2.82it/s]04:46:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:12 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 216/1782 [01:16<09:28,  2.76it/s]04:46:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:12 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 217/1782 [01:17<09:59,  2.61it/s]04:46:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:13 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 218/1782 [01:17<10:03,  2.59it/s]04:46:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:13 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 219/1782 [01:17<10:11,  2.56it/s]04:46:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:13 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 220/1782 [01:18<09:40,  2.69it/s]04:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:14 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 221/1782 [01:18<09:35,  2.71it/s]04:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:14 - cmdstanpy - INFO - Chain [1] done processing
#  12%|█▏        | 222/1782 [01:18<09:37,  2.70it/s]04:46:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:14 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 223/1782 [01:19<09:33,  2.72it/s]04:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:15 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 224/1782 [01:19<09:14,  2.81it/s]04:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:15 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 225/1782 [01:20<09:16,  2.80it/s]04:46:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:16 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 226/1782 [01:20<09:28,  2.74it/s]04:46:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:16 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 227/1782 [01:20<09:27,  2.74it/s]04:46:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:16 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 228/1782 [01:21<09:19,  2.78it/s]04:46:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:17 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 229/1782 [01:21<09:54,  2.61it/s]04:46:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:17 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 230/1782 [01:22<11:08,  2.32it/s]04:46:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:18 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 231/1782 [01:22<10:12,  2.53it/s]04:46:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:18 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 232/1782 [01:22<09:43,  2.66it/s]04:46:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:18 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 233/1782 [01:23<09:36,  2.69it/s]04:46:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:19 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 234/1782 [01:23<09:16,  2.78it/s]04:46:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:19 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 235/1782 [01:23<09:28,  2.72it/s]04:46:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:19 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 236/1782 [01:24<09:13,  2.79it/s]04:46:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:20 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 237/1782 [01:24<09:24,  2.74it/s]04:46:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:20 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 238/1782 [01:24<09:28,  2.72it/s]04:46:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:20 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 239/1782 [01:25<09:22,  2.74it/s]04:46:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:21 - cmdstanpy - INFO - Chain [1] done processing
#  13%|█▎        | 240/1782 [01:25<09:16,  2.77it/s]04:46:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:21 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▎        | 241/1782 [01:25<09:11,  2.79it/s]04:46:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:21 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▎        | 242/1782 [01:26<09:21,  2.74it/s]04:46:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:22 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▎        | 243/1782 [01:26<09:26,  2.72it/s]04:46:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:22 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▎        | 244/1782 [01:27<09:20,  2.74it/s]04:46:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:23 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▎        | 245/1782 [01:27<09:04,  2.82it/s]04:46:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:23 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 246/1782 [01:27<09:11,  2.78it/s]04:46:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:23 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 247/1782 [01:28<09:06,  2.81it/s]04:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:24 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 248/1782 [01:28<09:10,  2.79it/s]04:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:24 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 249/1782 [01:28<08:57,  2.85it/s]04:46:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:24 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 250/1782 [01:29<09:15,  2.76it/s]04:46:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:25 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 251/1782 [01:29<09:13,  2.77it/s]04:46:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:25 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 252/1782 [01:29<09:22,  2.72it/s]04:46:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:25 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 253/1782 [01:30<09:29,  2.69it/s]04:46:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:26 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 254/1782 [01:30<09:18,  2.73it/s]04:46:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:26 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 255/1782 [01:31<09:29,  2.68it/s]04:46:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:27 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 256/1782 [01:31<09:10,  2.77it/s]04:46:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:27 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 257/1782 [01:31<08:53,  2.86it/s]04:46:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:27 - cmdstanpy - INFO - Chain [1] done processing
#  14%|█▍        | 258/1782 [01:32<09:02,  2.81it/s]04:46:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:28 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 259/1782 [01:32<09:06,  2.79it/s]04:46:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:28 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 260/1782 [01:32<09:08,  2.78it/s]04:46:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:28 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 261/1782 [01:33<08:58,  2.82it/s]04:46:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:29 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 262/1782 [01:33<09:10,  2.76it/s]04:46:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:29 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 263/1782 [01:33<08:52,  2.85it/s]04:46:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:29 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 264/1782 [01:34<08:53,  2.84it/s]04:46:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:30 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 265/1782 [01:34<08:45,  2.89it/s]04:46:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:30 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 266/1782 [01:34<08:34,  2.95it/s]04:46:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:30 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▍        | 267/1782 [01:35<08:37,  2.93it/s]04:46:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:31 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 269/1782 [01:35<07:42,  3.27it/s]04:46:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:31 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 270/1782 [01:36<08:16,  3.05it/s]04:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:32 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 271/1782 [01:36<08:36,  2.93it/s]04:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:32 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 272/1782 [01:36<08:41,  2.90it/s]04:46:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:32 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 273/1782 [01:37<08:32,  2.95it/s]04:46:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:33 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 274/1782 [01:37<08:38,  2.91it/s]04:46:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:33 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 275/1782 [01:38<08:52,  2.83it/s]04:46:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:33 - cmdstanpy - INFO - Chain [1] done processing
#  15%|█▌        | 276/1782 [01:38<08:46,  2.86it/s]04:46:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:34 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 277/1782 [01:38<08:37,  2.91it/s]04:46:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:34 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 278/1782 [01:39<08:28,  2.96it/s]04:46:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:34 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 279/1782 [01:39<08:25,  2.97it/s]04:46:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 280/1782 [01:39<08:40,  2.88it/s]04:46:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:35 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 281/1782 [01:40<09:02,  2.77it/s]04:46:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:36 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 282/1782 [01:40<08:47,  2.84it/s]04:46:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:36 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 283/1782 [01:40<09:06,  2.74it/s]04:46:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:36 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 284/1782 [01:41<09:03,  2.75it/s]04:46:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:37 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 285/1782 [01:41<08:55,  2.79it/s]04:46:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:37 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 286/1782 [01:41<08:51,  2.82it/s]04:46:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:37 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 287/1782 [01:42<08:35,  2.90it/s]04:46:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:38 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 288/1782 [01:42<09:02,  2.75it/s]04:46:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:38 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 289/1782 [01:42<08:55,  2.79it/s]04:46:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:38 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▋        | 290/1782 [01:43<08:57,  2.78it/s]04:46:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:39 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▋        | 291/1782 [01:43<09:06,  2.73it/s]04:46:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:39 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▋        | 292/1782 [01:44<09:17,  2.67it/s]04:46:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:40 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▋        | 293/1782 [01:44<09:15,  2.68it/s]04:46:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:40 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▋        | 294/1782 [01:44<09:32,  2.60it/s]04:46:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:40 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 295/1782 [01:45<09:35,  2.58it/s]04:46:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:41 - cmdstanpy - INFO - Chain [1] done processing
#  17%|█▋        | 296/1782 [01:45<09:45,  2.54it/s]04:46:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:46:41 - cmdstanpy - INFO - Chain [1] done processing
# ...
#  94%|█████████▍| 1680/1782 [10:07<00:37,  2.73it/s]04:55:03 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:04 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 1681/1782 [10:08<00:38,  2.63it/s]04:55:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:04 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 1682/1782 [10:08<00:37,  2.68it/s]04:55:04 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:04 - cmdstanpy - INFO - Chain [1] done processing
#  94%|█████████▍| 1683/1782 [10:09<00:36,  2.69it/s]04:55:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:05 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1685/1782 [10:09<00:30,  3.19it/s]04:55:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:05 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1686/1782 [10:10<00:33,  2.89it/s]04:55:05 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:06 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1688/1782 [10:10<00:32,  2.87it/s]04:55:06 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:07 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1689/1782 [10:11<00:37,  2.47it/s]04:55:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:07 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1690/1782 [10:11<00:38,  2.39it/s]04:55:07 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:07 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1691/1782 [10:12<00:41,  2.21it/s]04:55:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:08 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 1692/1782 [10:12<00:42,  2.14it/s]04:55:08 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:08 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1693/1782 [10:13<00:41,  2.16it/s]04:55:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:09 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1694/1782 [10:13<00:41,  2.13it/s]04:55:09 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:09 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1695/1782 [10:14<00:41,  2.12it/s]04:55:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:10 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1696/1782 [10:14<00:44,  1.94it/s]04:55:10 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:10 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1697/1782 [10:15<00:41,  2.06it/s]04:55:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:11 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1698/1782 [10:15<00:37,  2.24it/s]04:55:11 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:11 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1699/1782 [10:16<00:36,  2.28it/s]04:55:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:12 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1700/1782 [10:16<00:36,  2.24it/s]04:55:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:12 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▌| 1701/1782 [10:16<00:35,  2.25it/s]04:55:12 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:13 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1702/1782 [10:17<00:36,  2.17it/s]04:55:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:13 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1703/1782 [10:17<00:35,  2.21it/s]04:55:13 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:13 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1704/1782 [10:18<00:34,  2.28it/s]04:55:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:14 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1705/1782 [10:18<00:33,  2.33it/s]04:55:14 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:14 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1706/1782 [10:19<00:32,  2.32it/s]04:55:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:15 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1707/1782 [10:19<00:33,  2.23it/s]04:55:15 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:15 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1708/1782 [10:20<00:34,  2.15it/s]04:55:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:16 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1709/1782 [10:20<00:34,  2.11it/s]04:55:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:16 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1710/1782 [10:21<00:32,  2.18it/s]04:55:16 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:17 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1711/1782 [10:21<00:32,  2.19it/s]04:55:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:17 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1712/1782 [10:22<00:32,  2.14it/s]04:55:17 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:18 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1713/1782 [10:22<00:32,  2.15it/s]04:55:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:18 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1714/1782 [10:23<00:33,  2.04it/s]04:55:18 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:19 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▌| 1715/1782 [10:23<00:33,  2.02it/s]04:55:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:19 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1716/1782 [10:23<00:31,  2.12it/s]04:55:19 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:19 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1717/1782 [10:24<00:29,  2.23it/s]04:55:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:20 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1718/1782 [10:24<00:26,  2.42it/s]04:55:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:20 - cmdstanpy - INFO - Chain [1] done processing
#  96%|█████████▋| 1719/1782 [10:25<00:25,  2.46it/s]04:55:20 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:21 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1720/1782 [10:25<00:26,  2.33it/s]04:55:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:21 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1721/1782 [10:25<00:24,  2.50it/s]04:55:21 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:21 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1722/1782 [10:26<00:24,  2.48it/s]04:55:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:22 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1723/1782 [10:26<00:23,  2.52it/s]04:55:22 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:22 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1724/1782 [10:27<00:24,  2.37it/s]04:55:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:23 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1725/1782 [10:27<00:26,  2.18it/s]04:55:23 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:23 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1726/1782 [10:28<00:25,  2.20it/s]04:55:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:24 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1727/1782 [10:28<00:24,  2.21it/s]04:55:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:24 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1728/1782 [10:29<00:23,  2.28it/s]04:55:24 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:25 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1729/1782 [10:29<00:22,  2.38it/s]04:55:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:25 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1730/1782 [10:29<00:21,  2.44it/s]04:55:25 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:25 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1731/1782 [10:30<00:20,  2.45it/s]04:55:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:26 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1732/1782 [10:30<00:20,  2.40it/s]04:55:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:26 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1733/1782 [10:30<00:19,  2.50it/s]04:55:26 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:26 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1734/1782 [10:31<00:18,  2.65it/s]04:55:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:27 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1735/1782 [10:31<00:18,  2.56it/s]04:55:27 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:27 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1736/1782 [10:32<00:18,  2.51it/s]04:55:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:28 - cmdstanpy - INFO - Chain [1] done processing
#  97%|█████████▋| 1737/1782 [10:32<00:17,  2.53it/s]04:55:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:28 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1738/1782 [10:32<00:16,  2.66it/s]04:55:28 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:28 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1739/1782 [10:33<00:15,  2.72it/s]04:55:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:29 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1740/1782 [10:33<00:15,  2.67it/s]04:55:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:29 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1741/1782 [10:34<00:15,  2.59it/s]04:55:29 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:30 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1742/1782 [10:34<00:15,  2.61it/s]04:55:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:30 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1743/1782 [10:34<00:14,  2.70it/s]04:55:30 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:30 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1744/1782 [10:35<00:15,  2.53it/s]04:55:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:31 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1745/1782 [10:35<00:14,  2.54it/s]04:55:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:31 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1746/1782 [10:36<00:14,  2.44it/s]04:55:31 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:32 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1747/1782 [10:36<00:14,  2.44it/s]04:55:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:32 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1748/1782 [10:36<00:12,  2.62it/s]04:55:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:32 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1749/1782 [10:37<00:12,  2.69it/s]04:55:32 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:33 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1750/1782 [10:37<00:11,  2.69it/s]04:55:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:33 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1751/1782 [10:37<00:11,  2.78it/s]04:55:33 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:33 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1752/1782 [10:38<00:10,  2.84it/s]04:55:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:34 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1754/1782 [10:38<00:09,  3.06it/s]04:55:34 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:34 - cmdstanpy - INFO - Chain [1] done processing
#  98%|█████████▊| 1755/1782 [10:39<00:09,  2.84it/s]04:55:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:35 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1756/1782 [10:39<00:09,  2.86it/s]04:55:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:35 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1757/1782 [10:39<00:09,  2.76it/s]04:55:35 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:35 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1758/1782 [10:40<00:08,  2.72it/s]04:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:36 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▊| 1759/1782 [10:40<00:08,  2.64it/s]04:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:36 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1760/1782 [10:41<00:08,  2.73it/s]04:55:36 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:37 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1761/1782 [10:41<00:07,  2.67it/s]04:55:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:37 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1762/1782 [10:41<00:07,  2.56it/s]04:55:37 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:37 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1763/1782 [10:42<00:07,  2.60it/s]04:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:38 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1764/1782 [10:42<00:06,  2.65it/s]04:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:38 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1765/1782 [10:42<00:06,  2.61it/s]04:55:38 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:38 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1766/1782 [10:43<00:06,  2.66it/s]04:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:39 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1767/1782 [10:43<00:05,  2.73it/s]04:55:39 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:39 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1770/1782 [10:44<00:03,  3.52it/s]04:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:40 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1771/1782 [10:44<00:03,  3.31it/s]04:55:40 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:40 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1772/1782 [10:45<00:03,  2.97it/s]04:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:41 - cmdstanpy - INFO - Chain [1] done processing
#  99%|█████████▉| 1773/1782 [10:45<00:03,  2.84it/s]04:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1774/1782 [10:45<00:02,  2.82it/s]04:55:41 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1775/1782 [10:46<00:02,  2.87it/s]04:55:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1776/1782 [10:46<00:02,  2.89it/s]04:55:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:42 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1777/1782 [10:47<00:01,  2.84it/s]04:55:42 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1778/1782 [10:47<00:01,  2.76it/s]04:55:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1779/1782 [10:47<00:01,  2.69it/s]04:55:43 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1780/1782 [10:48<00:00,  2.58it/s]04:55:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|█████████▉| 1781/1782 [10:48<00:00,  2.61it/s]04:55:44 - cmdstanpy - INFO - Chain [1] start processing
# 04:55:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 1782/1782 [10:48<00:00,  2.75it/s]

# %% [markdown]
# ### 2.4. Save Forecasts
# All predictions are combined and saved into `forecast_results.csv`, making them ready for evaluation or dashboard integration.

# %%
# Combine all forecasts and save
all_forecasts = pd.concat(forecast_results)
all_forecasts.to_csv("../forecasts/forecast_results.csv", index=False)
